# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import *

# %%
elec = eval("""[3933.683204
3577.119783
3566.349395
3335.213361
3299.099057
3468.3302
3401.3622
3840.8015
3614.9732
3581.9664
3591.23499
3481.2981
3179.3055
3180.7328
3577.755
3707.779
3638.8383
3603.821
3466.0974
3155.0505
2729.5634]""".replace('\n', ', '))


level = eval("""[3665.32
3637.85
3607.89
3579.88
3585.86
3600.83
3602.38
3612.42
3626.56
3628.63
3635.90 
3628.87
3595.83
3593.79
3610.47
3604.74
3616.94
3604.11
3596.95
3600.11
3557.57]""".replace('\n', ', '))

# %%
plt.plot(np.arange(0, len(elec), 1), elec, label = "electricity", c='r')
plt.plot(np.arange(0, len(level), 1), level, label="level", c='b')
plt.show()

# %%
df = pd.DataFrame(elec, columns=['elec'])
df['level'] = level
df['year'] = np.arange(0, len(elec), 1)

# %%
fig = plt.figure(figsize =(12,3))
fig.add_subplot(1,2,1)
plt.scatter(df['level'],df['elec'],marker = '.',color = 'k')
plt.grid(True)

# %%
# elec = a * level + b
model = linear_model.LinearRegression()
model.fit(df['level'][:,np.newaxis], df['elec'][:,np.newaxis])
# Out:
# C:\Users\Sycamore\AppData\Local\Temp\ipykernel_13252\50050713.py:3: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   model.fit(df['level'][:,np.newaxis], df['elec'][:,np.newaxis])
# LinearRegression()

# %%
x_test = np.arange(3500, 3700, 1)[:,np.newaxis]
print(x_test.shape)
y_predict = model.predict(x_test)
plt.plot(x_test, y_predict)
# Out:
# (200, 1)

# %%
print('slope: %.4f' % model.coef_[0])
print('intercept: %.4f' % model.intercept_)
print('The linear regression function: y = %.4fx + %.4f' %
      (model.coef_[0], model.intercept_))
# Out:
# slope: 8.9611
# intercept: -28869.5582
# The linear regression function: y = 8.9611x + -28869.5582
